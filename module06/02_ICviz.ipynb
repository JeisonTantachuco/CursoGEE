# %% [markdown]
# <a href="https://colab.research.google.com/github/JeisonTantachuco/CursoGEE/blob/main/module06/02_ICviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <!--COURSE_INFORMATION-->
# <img align="left" style="padding-right:10px;" src="https://user-images.githubusercontent.com/16768318/73986808-75b3ca00-4936-11ea-90f1-3a6c352766ce.png" width=10% >
# <img align="right" style="padding-left:10px;" src="https://user-images.githubusercontent.com/16768318/73986811-764c6080-4936-11ea-9653-a3eacc47caed.png" width=10% >
#
# **Bienvenidos!** Este *colab notebook* es parte del curso [**Introduccion a Google Earth Engine con Python**](https://github.com/csaybar/EarthEngineMasterGIS) desarrollado por el equipo [**MasterGIS**](https://www.mastergis.com/). Obten mas informacion del curso en este [**enlace**](https://www.mastergis.com/product/google-earth-engine-python/). El contenido del curso esta disponible en [**GitHub**](https://github.com/csaybar/EarthEngineMasterGIS) bajo licencia [**MIT**](https://opensource.org/licenses/MIT).

# %% [markdown]
# ## **MASTERGIS: Visualizacion de un ee.ImageCollection**
#
# En esta lectura, aprenderemos sobre como realizar vizualizaciones en colecciones de imagenes.

# %%
#@title Credenciales Google Earth Engine
import ee
ee.Authenticate()
ee.Initialize(project = 'ee-jtantaroman')

# %%
#@title mapdisplay: Crea mapas interactivos usando folium
import folium
def mapdisplay(center, dicc, Tiles="OpensTreetMap",zoom_start=10):
    '''
    :param center: Center of the map (Latitude and Longitude).
    :param dicc: Earth Engine Geometries or Tiles dictionary
    :param Tiles: Mapbox Bright,Mapbox Control Room,Stamen Terrain,Stamen Toner,stamenwatercolor,cartodbpositron.
    :zoom_start: Initial zoom level for the map.
    :return: A folium.Map object.
    '''
    center = center[::-1]
    mapViz = folium.Map(location=center,tiles=Tiles, zoom_start=zoom_start)
    for k,v in dicc.items():
      if ee.image.Image in [type(x) for x in v.values()]:
        folium.TileLayer(
            tiles = v["tile_fetcher"].url_format,
            attr  = 'Google Earth Engine',
            overlay =True,
            name  = k
          ).add_to(mapViz)
      else:
        folium.GeoJson(
        data = v,
        name = k
          ).add_to(mapViz)
    mapViz.add_child(folium.LayerControl())
    return mapViz

# %%
# !pip install earthengine-api==0.1.210 esto ya no es necesario en ultima versiones

# %% [markdown]
# ### **Ejercicio**
#
# Las animaciones de series temporales de imagenes satelitales son una forma atractivas de mostrar tus resultados. En esta seccion, aprenderemos como generar un GIF animado que represente un **NDVI promedio de 20 anos para compuestos MODIS de 16 dias que abarcan del 1 de enero al 31 de diciembre**.
# <center>
# <img src='https://user-images.githubusercontent.com/16768318/73617762-142fea80-461a-11ea-8c8a-0a124a0735c1.gif'>
# </center>

# %% [markdown]
# #### **Contexto**
#
# **MODIS** es un sistema de imagenes satelitales de resolución moderada y el **NDVI** es un indice de vegetacion basado en bandas reflectancia. En la animacion superior, el NDVI se asigna a un gradiente de color de marron a verde oscuro, representando una capacidad fotosintetica baja a alta respectivamente.

# %% [markdown]
# **Instrucciones**
#
# El flujo de trabajo basico para realizar una animacion es el siguiente:
#
# 1. Definir region de interes.
#
# 2. Obtenga el conjunto de datos de indices de vegetación MODIS y seleccione la banda de NDVI.
#
# 3. **Agrupe las imagenes de la misma ventana temporal (16 dias) utilizando un _join_**.
#
# 4. Reduzca el grupo de compuestos de NDVI (por la media) para producir la animacion.
#
# 5. Defina los parametros de visualizacion y convierta los datos en imagenes de visualizacion RGB.
#
# 6. Genere una URL que produzca un GIF en el navegador

# %% [markdown]
# ### **1. Area de estudio**
# La variable **mask** sera usada para recortar las imagenes, este es un paso opcional que establece los pixeles fuera de un area de interes como nulos, lo que es util para exhaltar los valores sobre un area particular dentro de una region. Aqui, el conjunto de datos vectoriales **LSIB** se filtra para incluir solo la geometria de Peru (que servira como geometria de recorte).
#
# **geom_Peru** es utilizado dentro de _ee.ImageCollection.filterBounds()_.

# %%
#Los limites de los paises ya se encuentra en una capa en la bd de gee
mask = ee.FeatureCollection('USDOS/LSIB_SIMPLE/2017')\
         .filter(ee.Filter.eq('country_co', 'PE'))
geom_peru = mask.geometry().bounds() #Poligono que contiene los limites norte,sur,este y oeste del peru

# %%
mapdisplay([-76,-12],{'peru':mask.getInfo()})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_671335e0f78e782c449e0b48abe3769d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_671335e0f78e782c449e0b48abe3769d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_671335e0f78e782c449e0b48abe3769d = L.map(
#                 &quot;map_671335e0f78e782c449e0b48abe3769d&quot;,
#                 {
#                     center: [-12.0, -76.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38c6daf1e7f86dda163325116f7873d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_38c6daf1e7f86dda163325116f7873d0.addTo(map_671335e0f78e782c449e0b48abe3769d);
#
#
#
#         function geo_json_b8056749035144a66833401a63873876_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b8056749035144a66833401a63873876 = L.geoJson(null, {
#                 onEachFeature: geo_json_b8056749035144a66833401a63873876_onEachFeature,
#
#         });
#
#         function geo_json_b8056749035144a66833401a63873876_add (data) {
#             geo_json_b8056749035144a66833401a63873876
#                 .addData(data);
#         }
#             geo_json_b8056749035144a66833401a63873876_add({&quot;columns&quot;: {&quot;abbreviati&quot;: &quot;String&quot;, &quot;country_co&quot;: &quot;String&quot;, &quot;country_na&quot;: &quot;String&quot;, &quot;system:index&quot;: &quot;String&quot;, &quot;wld_rgn&quot;: &quot;String&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-80.22179325601519, -3.440277993192948], [-80.2219061026833, -3.440230983038645], [-80.22138697272912, -3.4381549798928885], [-80.22164687851526, -3.4369880751181934], [-80.22229595868585, -3.4358200420069305], [-80.2237219262605, -3.435301976659732], [-80.22631713270688, -3.4353019749980436], [-80.22748791116038, -3.4357699918145754], [-80.22774890456678, -3.433136011639979], [-80.23024876723746, -3.431093476552311], [-80.2364392636019, -3.4268447655408094], [-80.23812195640582, -3.4263510030854403], [-80.2460913206576, -3.426377005658992], [-80.25148293278608, -3.427129016130046], [-80.25545159850586, -3.4266327987595218], [-80.26134193982426, -3.4245340253755634], [-80.26419602721104, -3.4238860331686585], [-80.26692013514848, -3.423886012361724], [-80.27405500111527, -3.4264799747088994], [-80.27716788554339, -3.426220965514471], [-80.27833609130028, -3.4295939715104162], [-80.27859488717537, -3.4311500049846155], [-80.27833609130028, -3.432967046106839], [-80.27924404206026, -3.4332260363610954], [-80.27989310691909, -3.4288149865467057], [-80.27937399150304, -3.4247940601723412], [-80.28067100867344, -3.424404950413748], [-80.28430307819247, -3.4237559917594615], [-80.28715715677241, -3.4229779768946624], [-80.29091913446159, -3.4211620177392827], [-80.29299495334247, -3.4194750652417807], [-80.29455084870197, -3.417139957091355], [-80.29545913549941, -3.417011018575058], [-80.30096255616739, -3.4105618147216994], [-80.3033161482681, -3.4078950775453554], [-80.30518812621978, -3.4062429643762657], [-80.30596715540253, -3.4061139946342354], [-80.30700505629389, -3.4061139522486292], [-80.30869093788324, -3.4066329924617627], [-80.30778296348277, -3.4032600109875926], [-80.30852660204239, -3.4034170001640542], [-80.30882985370387, -3.4041940501844925], [-80.30969207885207, -3.4050549250829456], [-80.31082106867767, -3.4095439570234696], [-80.3116414471347, -3.413152768124347], [-80.31204848790854, -3.414943573769253], [-80.31248035024059, -3.416668684515044], [-80.31290727968697, -3.4182860831381303], [-80.31383517643523, -3.4225278145857816], [-80.3146579058444, -3.424923996851371], [-80.31676442377852, -3.4309255099928757], [-80.31845521062057, -3.4350731428132715], [-80.3191173199659, -3.4365906915564364], [-80.32026624457092, -3.4392241390288634], [-80.32133482559777, -3.4408333161747753], [-80.3229751998822, -3.4441666467305403], [-80.33633424568714, -3.4566667000239395], [-80.33633424568714, -3.457527884327969], [-80.33885954060159, -3.46086119632555], [-80.34130861500613, -3.46752790140028], [-80.34880828103405, -3.4750554574234673], [-80.35130312089142, -3.479194393411844], [-80.35130312089142, -3.4825277400442487], [-80.35216525098221, -3.484194487505051], [-80.35422511636166, -3.4862498924849827], [-80.35671996526766, -3.4871111281675327], [-80.36260986648291, -3.4929721055964893], [-80.36672206765886, -3.494583347763129], [-80.37002564987978, -3.4987778585223293], [-80.38341518315875, -3.50544451852461], [-80.3859481501852, -3.5054721534363975], [-80.38838956534055, -3.507138984406289], [-80.39341732780764, -3.5079443779634083], [-80.39675136515028, -3.5104723004763634], [-80.40005495193178, -3.512138829578609], [-80.4017486477133, -3.512138832936361], [-80.40589145076619, -3.5146109861192847], [-80.40758

# %% [markdown]
# ### **2. Filtrando dataset**
# **ee.Date.getRelative(...)**: Devuelve la diferencia (considerando desde 0) de esta fecha en relación con una unidad mas grande, por ejemplo, **getRelative('day', 'year')** devuelve un valor entre 0 y 365.

# %%
# Cargamos los datos de NDVI de MODIS
col = ee.ImageCollection('MODIS/006/MOD13A2').select('NDVI')

# Agregamos la propiedad day-of-year (DOY) para cada imagen
# GEE trabaja las fechs utilizando time stamp (utilizando como fecha de partida a 01-01-1970), pero Modis utiliza dias julianos es decir del 0 al 365 y el año al costado ejem
# 32 2010 vendria a ser el 01-02-2010
def add_day(img):
  doy = ee.Date(img.get('system:time_start')).getRelative('day', 'year') #Transforma las fechas de 0 a 365 (porque se esta utilizando como parametro superior year, si fuera week seria de 1 al 7)
  return img.set('doy', doy)

col = col.map(add_day)
col.first().getInfo()
#Doy : 48, fecha de la primera imagen es 17 de febrero
# Out:
# /usr/local/lib/python3.10/dist-packages/ee/deprecation.py:207: DeprecationWarning:
#
# Attention required for MODIS/006/MOD13A2! You are using a deprecated asset.
# To ensure continued functionality, please update it.
# Learn more: https://developers.google.com/earth-engine/datasets/catalog/MODIS_006_MOD13A2
#
#   warnings.warn(warning, category=DeprecationWarning)
# {'type': 'Image',
#  'bands': [{'id': 'NDVI',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [43200, 21600],
#    'crs': 'SR-ORG:6974',
#    'crs_transform': [926.625433056,
#     0,
#     -20015109.354,
#     0,
#     -926.625433055,
#     10007554.677]}],
#  'version': 1638764935442440.0,
#  'id': 'MODIS/006/MOD13A2/2000_02_18',
#  'properties': {'doy': 48,
#   'system:time_start': 950832000000,
#   'google:max_source_file_timestamp': 1528310897320,
#   'system:footprint': {'type': 'LinearRing',
#    'coordinates': [[-180, -90],
#     [180, -90],
#     [180, 90],
#     [-180, 90],
#     [-180, -90]]},
#   'system:time_end': 952214400000,
#   'system:asset_size': 2806855579,
#   'system:index': '2000_02_18'}}

# %% [markdown]
# ### **3. Join**
#
# **Join en GEE nos permite agrupar imagenes o features mediante propiedades**. Para este ejercicio, se implementara una operacion **join** para agrupar dos grupos de imagenes (ImageCollection) bajo la propiedad **'doy'** que acabamos de generar en la celda anterior.
#
# **ee.join** siempre espera dos colecciones: una **coleccion de referencia** y una **coleccion completa**, que al final sera modificada para incluir las propiedades de la **coleccion de referencia**. La coleccion completa (col) ya existe, la **colección de referencia** necesita ser definida. Para ello, filtre la coleccion completa en un solo año de datos (no importa el año que escoja), por ejemplo 2013.
#
# Para crear un **ee.join** considere:
#
# 1. Crear un filtro que identificara imagenes coincidentes entre la **coleccion de referencia** y **coleccion completa** por la propiedad **doy**.
# 2. Defina un **saveALL join**  que producira una lista de todas las coincidencias por **'doy'** distintas en una propiedad llamada **'doy_matches'**.
# 3. Aplicando la **join**.
#
# **TENER EN CUENTA QUE luego de aplicar un ee.Join.SaveAll el resultado siempre sera un ee.FeatureCollection**

# %%
# Obtenga una colección de imagenes distintas de 'doy' (COLLECCION DE REFERENCIA).
distinctDOY = col.filterDate('2013-01-01', '2014-01-01')

# Defina un filtro que identifique que imagenes de la 'coleccion completa'
# coincide con el DOY de la colección de referencia.
my_filter = ee.Filter.equals(leftField = 'doy', rightField = 'doy')

# Define el Join
join = ee.Join.saveAll('doy_matches')

#Visualizar el resultado, el resultado siempre va a ser un feature collection pero sin geometrias
join.apply(distinctDOY, col, my_filter).first().getInfo()

#ctrl + f y busca system:index, vamos a encontrar que nuestra base de datos de referencia que empezó con 2013-01-01 (doy 0) ha hecho match con todas las imagenes de doy0 de la base de datos general y con el system index veremos que son los 01-01 de todos los años
# Out:
# {'type': 'Image',
#  'bands': [{'id': 'NDVI',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [43200, 21600],
#    'crs': 'SR-ORG:6974',
#    'crs_transform': [926.625433056,
#     0,
#     -20015109.354,
#     0,
#     -926.625433055,
#     10007554.677]}],
#  'version': 1638765084595611,
#  'id': 'MODIS/006/MOD13A2/2013_01_01',
#  'properties': {'doy_matches': [{'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638764945654270.0,
#     'id': 'MODIS/006/MOD13A2/2001_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 978307200000,
#      'google:max_source_file_timestamp': 1528309231052,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 979689600000,
#      'system:asset_size': 2620015328,
#      'system:index': '2001_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638764956796349,
#     'id': 'MODIS/006/MOD13A2/2002_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1009843200000,
#      'google:max_source_file_timestamp': 1528309301440,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1011225600000,
#      'system:asset_size': 2610091464,
#      'system:index': '2002_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638764968023657,
#     'id': 'MODIS/006/MOD13A2/2003_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1041379200000,
#      'google:max_source_file_timestamp': 1528310836260,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1042761600000,
#      'system:asset_size': 2608505455,
#      'system:index': '2003_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638764979514160.0,
#     'id': 'MODIS/006/MOD13A2/2004_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1072915200000,
#      'google:max_source_file_timestamp': 1528309146984,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1074297600000,
#      'system:asset_size': 2626189063,
#      'system:index': '2004_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638764991205641,
#     'id': 'MODIS/006/MOD13A2/2005_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1104537600000,
#      'google:max_source_file_timestamp': 1528309295931,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1105920000000,
#      'system:asset_size': 2616404495,
#      'system:index': '2005_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765002983524,
#     'id': 'MODIS/006/MOD13A2/2006_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1136073600000,
#      'google:max_source_file_timestamp': 1528225303800,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1137456000000,
#      'system:asset_size': 2619730442,
#      'system:index': '2006_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765014730791,
#     'id': 'MODIS/006/MOD13A2/2007_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1167609600000,
#      'google:max_source_file_timestamp': 1528229937266,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1168992000000,
#      'system:asset_size': 2626031858,
#      'system:index': '2007_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765026175582,
#     'id': 'MODIS/006/MOD13A2/2008_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1199145600000,
#      'google:max_source_file_timestamp': 1528227516630,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1200528000000,
#      'system:asset_size': 2629459894,
#      'system:index': '2008_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765038078592,
#     'id': 'MODIS/006/MOD13A2/2009_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1230768000000,
#      'google:max_source_file_timestamp': 1528229419409,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1232150400000,
#      'system:asset_size': 2629106995,
#      'system:index': '2009_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765049732413,
#     'id': 'MODIS/006/MOD13A2/2010_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1262304000000,
#      'google:max_source_file_timestamp': 1528228975528,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1263686400000,
#      'system:asset_size': 2622883958,
#      'system:index': '2010_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765061556315,
#     'id': 'MODIS/006/MOD13A2/2011_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1293840000000,
#      'google:max_source_file_timestamp': 1528230609457,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1295222400000,
#      'system:asset_size': 2635673531,
#      'system:index': '2011_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765073042288,
#     'id': 'MODIS/006/MOD13A2/2012_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1325376000000,
#      'google:max_source_file_timestamp': 1528227174997,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1326758400000,
#      'system:asset_size': 2624454436,
#      'system:index': '2012_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765084595611,
#     'id': 'MODIS/006/MOD13A2/2013_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1356998400000,
#      'google:max_source_file_timestamp': 1528226722252,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1358380800000,
#      'system:asset_size': 2647320514,
#      'system:index': '2013_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765096829096,
#     'id': 'MODIS/006/MOD13A2/2014_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1388534400000,
#      'google:max_source_file_timestamp': 1528224965015,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1389916800000,
#      'system:asset_size': 2635263359,
#      'system:index': '2014_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765108775875,
#     'id': 'MODIS/006/MOD13A2/2015_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1420070400000,
#      'google:max_source_file_timestamp': 1528227565285,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1421452800000,
#      'system:asset_size': 2624916921,
#      'system:index': '2015_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765121159851,
#     'id': 'MODIS/006/MOD13A2/2016_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1451606400000,
#      'google:max_source_file_timestamp': 1454559132000,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1452988800000,
#      'system:asset_size': 2643108679,
#      'system:index': '2016_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765133756548,
#     'id': 'MODIS/006/MOD13A2/2017_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1483228800000,
#      'google:max_source_file_timestamp': 1528227613291,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1484611200000,
#      'system:asset_size': 2645516981,
#      'system:index': '2017_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765146236423,
#     'id': 'MODIS/006/MOD13A2/2018_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1514764800000,
#      'google:max_source_file_timestamp': 1528229702056,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1516147200000,
#      'system:asset_size': 2638887523,
#      'system:index': '2018_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765158753399,
#     'id': 'MODIS/006/MOD13A2/2019_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1546300800000,
#      'google:max_source_file_timestamp': 1548430633000,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1547683200000,
#      'system:asset_size': 2643261840,
#      'system:index': '2019_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433056,
#        0,
#        -20015109.354,
#        0,
#        -926.625433055,
#        10007554.677]}],
#     'version': 1638765170873988,
#     'id': 'MODIS/006/MOD13A2/2020_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1577836800000,
#      'google:max_source_file_timestamp': 1579484413000,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1579219200000,
#      'system:asset_size': 2629012179,
#      'system:index': '2020_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433055833,
#        0,
#        -20015109.353988,
#        0,
#        -926.6254330549998,
#        10007554.676994]}],
#     'version': 1611168259564074,
#     'id': 'MODIS/006/MOD13A2/2021_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1609459200000,
#      'google:max_source_file_timestamp': 1610986389000,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1610841600000,
#      'system:asset_size': 2618821375,
#      'system:index': '2021_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 21600],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433055833,
#        0,
#        -20015109.353988,
#        0,
#        -926.6254330549998,
#        10007554.676994]}],
#     'version': 1642622235264987,
#     'id': 'MODIS/006/MOD13A2/2022_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1640995200000,
#      'google:max_source_file_timestamp': 1642559121000,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1642377600000,
#      'system:asset_size': 2625020113,
#      'system:index': '2022_01_01'}},
#    {'type': 'Image',
#     'bands': [{'id': 'NDVI',
#       'data_type': {'type': 'PixelType',
#        'precision': 'int',
#        'min': -32768,
#        'max': 32767},
#       'dimensions': [43200, 16800],
#       'crs': 'SR-ORG:6974',
#       'crs_transform': [926.625433055833,
#        0,
#        -20015109.354,
#        0,
#        -926.6254330558334,
#        8895604.157336]}],
#     'version': 1674167512272532,
#     'id': 'MODIS/006/MOD13A2/2023_01_01',
#     'properties': {'doy': 0,
#      'system:time_start': 1672531200000,
#      'google:max_source_file_timestamp': 1674147907000,
#      'system:footprint': {'type': 'LinearRing',
#       'coordinates': [[-180, -90],
#        [180, -90],
#        [180, 90],
#        [-180, 90],
#        [-180, -90]]},
#      'system:time_end': 1673913600000,
#      'system:asset_size': 2621185562,
#      'system:index': '2023_01_01'}}],
#   'doy': 0,
#   'system:time_start': 1356998400000,
#   'google:max_source_file_timestamp': 1528226722252,
#   'system:footprint': {'type': 'LinearRing',
#    'coordinates': [[-180, -90],
#     [180, -90],
#     [180, 90],
#     [-180, 90],
#     [-180, -90]]},
#   'system:time_end': 1358380800000,
#   'system:asset_size': 2647320514,
#   'system:index': '2013_01_01'}}

# %%
# Los resultados no se guardan en bandas, se guardan en propiedades, lo que se debe hacer es extraer esas propiedades
# Para eso primero pasaremos el feature collection a image collection para luego aplicarle un map, y extraer las propiedades doy_matches que es una lista de imagenes que hizo match

# Aplicar el join y convertir el FeatureCollection resultante en un ImageCollection.
joinCol = ee.ImageCollection(join.apply(distinctDOY, col, my_filter))

# Aplicar la mediana entre las colecciones DOY coincidentes.
def reduce_each_image(img):
  doyCol = ee.ImageCollection.fromImages(img.get('doy_matches')) #Aca se esta generando el image collection de la lista de imagenes, exiten listas para cada grupo que hizo match, doy = 0 (imagenes del 01-01 de todos los años), doy = 16 (imagenes del 16-01 de todos los años), etc ..
  return doyCol.reduce(ee.Reducer.median())  #Aca se genera un image (agrupamos cada lista de los doy 0, 16 ,etc; la agrupacion saca la mediana (imagen de una sola banda ya no image collection)), pero serian la n cantidad de imagenes igual a la cantidad de doys en el año 0,16,32 etc.

comp = joinCol.map(reduce_each_image)

# %% [markdown]
# #### **4. Hacer imagenes de visualizacion**
#
# Establezca las propiedades de visualizacion (**ee.Image.vizualize**) para controlar la apariencia de los datos en los cuadros de animacion. Defina las propiedades de visualizacion que incluyen una paleta de colores y valores minimos y maximos para estirar o comprimir la paleta. Asigne el metodo de visualizacion sobre cada imagen utilizando las propiedades de visualizacion definidas y recorte los datos a la mascara definida en el seccin 1 para establecer los pixeles de fondo nulo (negro).

# %%
def vizparam(img):
  # Parametros de vizualicion.
  return img.visualize(
       min = 0.0,
       max = 9000.0,
       palette = ['FFFFFF', 'CE7E45', 'DF923D', 'F1B555', 'FCD163', '99B718', '74A901',
                  '66A000', '529400', '3E8601', '207401', '056201', '004C00', '023B01',
                  '012E01', '011D01', '011301']
                ).clip(mask)

# %% [markdown]
# ### **5. Crea un GIF animado**
#
# El paso final es definir argumentos para el método **getVideoThumbURL** que creara una animación a partir de la colección de imágenes de visualización RGB generadas en el paso anterior. Los parámetros relevantes incluyen:
#
# region: establecer en la región definida en el Paso 2 anterior
# dimensiones: establecido en 600 que define la dimensión más grande del GIF resultante como 600px (la dimensión más pequeña se escala proporcionalmente)
# crs: establecido en 'EPSG: 3857' para que coincida con el sistema de referencia de coordenadas del mapa del editor de código
# framesPerSecond: establecido en 10 (cuadros por segundo)

# %%
# Create RGB visualization images for use as animation frames.
rgbVis = comp.map(vizparam)

# Define GIF visualization arguments.
gifParams = {
  'region': geom_peru,
  'dimensions': 600,
  'crs': 'EPSG:4326',
  'framesPerSecond': 4,
  'format': 'gif'
}

# Print the GIF URL to the console.
gif = rgbVis.getVideoThumbURL(gifParams)

# %%
from IPython.display import Image
from IPython.core.display import HTML
Image(url= gif)
# Out:
# <img src="https://earthengine.googleapis.com/v1/projects/ee-jtantaroman/videoThumbnails/552ada68a8ec8bc8b3379f10d9aa990c-0ca7b8565480b85ea54fc85437eb755d:getPixels"/>

# %% [markdown]
# #### **Funcion para crear animaciones de NDVI en cualquier parte del mundo**

# %%
def monthly_ndvi_animation(area, vizparams = None, framesPerSecond = 10):
  if vizparams is None:
    vizparams = {'min' : 0.0,
                 'max' : 9000.0,
                 'palette' : ['#051852', '#FFFFFF', '#C7B59B', '#A8B255',
                              '#A3C020', '#76AD00', '#429001', '#006400',
                              '#003B00', '#000000']
                 }
  # Cargamos los datos de NDVI de MODIS
  col = ee.ImageCollection('MODIS/006/MOD13A2').select('NDVI')

  # Agregamos la propiedad day-of-year (DOY) para cada imagen
  def add_day(img):
    doy = ee.Date(img.get('system:time_start')).getRelative('day', 'year')
    return img.set('doy', doy)

  col = col.map(add_day)

  # Obtenga una colección de imágenes distintas de 'doy'.
  distinctDOY = col.filterDate('2013-01-01', '2014-01-01')

  # Defina un filtro que identifique que imagenes de la 'coleccion completa'
  # coincide con el DOY de la colección de referencia.
  my_filter = ee.Filter.equals(leftField = 'doy', rightField = 'doy')

  # Define el Join
  join = ee.Join.saveAll('doy_matches')

  # Aplicar el join y convertir el FeatureCollection resultante en un ImageCollection.
  joinCol = ee.ImageCollection(join.apply(distinctDOY, col, my_filter))

  # Aplicar la mediana entre las colecciones DOY coincidentes.
  def reduce_each_image(img):
    doyCol = ee.ImageCollection.fromImages(img.get('doy_matches'))
    return doyCol.reduce(ee.Reducer.median())

  comp = joinCol.map(reduce_each_image)

  # Cree imagenes de visualizacion RGB para usar como cuadros de animacion.
  rgbVis = comp.map(lambda x:x.visualize(**vizparams).clip(area))

  # Definir argumentos de visualización GIF.
  gifParams = {
    'region': area.bounds(),
    'dimensions': 600,
    'crs': 'EPSG:3857',
    'framesPerSecond': framesPerSecond,
    'format': 'gif'
  }
  # Imprima la URL GIF en la consola.
  return rgbVis.getVideoThumbURL(gifParams)

# %%
ecuador = ee.Geometry.Polygon([
          [
            [
              -82.37548828125,
              -5.7908968128719565
            ],
            [
              -74.86083984375,
              -5.7908968128719565
            ],
            [
              -74.86083984375,
              1.9551868337565232
            ],
            [
              -82.37548828125,
              1.9551868337565232
            ],
            [
              -82.37548828125,
              -5.7908968128719565
            ]
          ]
        ])
monthly_ndvi_animation(ecuador, framesPerSecond = 5)
# Out:
# 'https://earthengine.googleapis.com/v1/projects/ee-jtantaroman/videoThumbnails/924f7dd4bf928fde582a435364aa4b2f-be634e54a4f9071c75495247d3389666:getPixels'

# %% [markdown]
# ### **¿Dudas con este Jupyer-Notebook?**
#
# Estaremos felices de ayudarte!. Create una cuenta Github si es que no la tienes, luego detalla tu problema ampliamente en: https://github.com/csaybar/EarthEngineMasterGIS/issues
#
# **Tienes que dar clic en el boton verde!**
#
# <center>
# <img src="https://user-images.githubusercontent.com/16768318/79680748-d5511000-81d8-11ea-9f89-44bd010adf69.png" width = 70%>
# </center>
