# %% [markdown]
# <!--COURSE_INFORMATION-->
# <img align="left" style="padding-right:10px;" src="https://user-images.githubusercontent.com/16768318/73986808-75b3ca00-4936-11ea-90f1-3a6c352766ce.png" width=10% >
# <img align="right" style="padding-left:10px;" src="https://user-images.githubusercontent.com/16768318/73986811-764c6080-4936-11ea-9653-a3eacc47caed.png" width=10% >
#
# **Bienvenidos!** Este *colab notebook* es parte del curso [**Introduccion a Google Earth Engine con Python**](https://github.com/csaybar/EarthEngineMasterGIS) desarrollado por el equipo [**MasterGIS**](https://www.mastergis.com/). Obten mas informacion del curso en este [**enlace**](https://www.mastergis.com/product/google-earth-engine/). El contenido del curso esta disponible en [**GitHub**](https://github.com/csaybar/EarthEngineMasterGIS) bajo licencia [**MIT**](https://opensource.org/licenses/MIT).

# %% [markdown]
# ## **MASTERGIS: Clasificacion de Imagenes Satelitales**
#
# En esta lectura, aprenderemos sobre:
#
# - **Clasificacion supervisada**.
# - **Clasificacion no supervisada**.
# <center>
# <img src='https://user-images.githubusercontent.com/16768318/73627817-0a23e100-4646-11ea-83f4-07293b85c4d9.png' width = 50% align="right">
#
# <img src='https://user-images.githubusercontent.com/16768318/73627849-2aec3680-4646-11ea-9dd3-b52b13652833.gif' width = 30% align="left">
# </center>

# %% [markdown]
# https://www.mdpi.com/2072-4292/11/23/2881
#
#
# Se recomienda utilizar otras librerias en python para hacer los modelos de ML, como sckit-learn, tensor flow, keras y otros, sin embargo, en GEE tambien se pueden generar modelos pero son muy limitados. Asi que lo mejor es realizar el modelo en local en python, y luego subir el modelo para predecir en gee.

# %%
#@title Credenciales Google Earth Engine
import ee
ee.Authenticate()
ee.Initialize(project = 'ee-jtantaroman')

# %%
#@title mapdisplay: Crea mapas interactivos usando folium
import folium
def mapdisplay(center, dicc, Tiles="OpensTreetMap",zoom_start=10):
    '''
    :param center: Center of the map (Latitude and Longitude).
    :param dicc: Earth Engine Geometries or Tiles dictionary
    :param Tiles: Mapbox Bright,Mapbox Control Room,Stamen Terrain,Stamen Toner,stamenwatercolor,cartodbpositron.
    :zoom_start: Initial zoom level for the map.
    :return: A folium.Map object.
    '''
    center = center[::-1]
    mapViz = folium.Map(location=center,tiles=Tiles, zoom_start=zoom_start)
    for k,v in dicc.items():
      if ee.image.Image in [type(x) for x in v.values()]:
        folium.TileLayer(
            tiles = v["tile_fetcher"].url_format,
            attr  = 'Google Earth Engine',
            overlay =True,
            name  = k
          ).add_to(mapViz)
      else:
        folium.GeoJson(
        data = v,
        name = k
          ).add_to(mapViz)
    mapViz.add_child(folium.LayerControl())
    return mapViz

# %% [markdown]
# ### **1. Clasificación supervisada**
# El modulo **ee.Classifier** maneja la clasificacion supervisada en Earth Engine. El flujo de trabajo general para la clasificacion es:
#
# 1. Recopilar datos de entrenamiento. Reuna puntos que tienen como propiedad el **"target"** y las variables predictoras.
#
# 2. Instanciar un clasificador. Establezca sus parametros si es necesario.
#
# 3. Entrene al clasificador utilizando los datos de entrenamiento.
#
# 4. Clasificar una imagen o FeatureCollection.
#
# 5. Estime el error de clasificacion con datos de validacion independientes.
#
#
# Los datos de entrenamiento siempre deben definirse como un **ee.FeatureCollection** con una propiedad que almacene el target y propiedades que almacenen las variables predictoras. El **target** debe ser enteros pequeños, consecutivos y no negativos que representen clases. Si es necesario, utilice **remap()** para convertir los valores de clase en enteros consecutivos a partir de 0. Los predictores deben ser numericos.
#
# Obtenga un clasificador de uno de los constructores en **ee.Classifier**. Entrene al clasificador usando **classifier.train()**. Clasifique una imagen o FeatureCollection usando **classify()**. El siguiente ejemplo utiliza un clasificador de arboles de clasificacion y regresion (CART) (Breiman et al. 1984) para predecir areas forestales y no forestales en la Amazonia:

# %%
# Cargar puntos de entrenamiento. La propiedad numerica 'clase' almacena etiquetas conocidas
points = ee.FeatureCollection('GOOGLE/EE/DEMOS/demo_landcover_labels')

# Las imagenes de entrada son un compuesto Landsat 8 sin nubes.
l8 = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')\
       .filterBounds(points)

# Filtrar las imagenes por score de nubes y percentiles (% de nubes que presenta la imagen)
# Use the 'quality band' to mask out cloudy pixels before compositing
image = l8.filterDate('2018-01-01', '2018-12-31') \
    .map(lambda img: img.updateMask(img.select('QA_PIXEL').bitwiseAnd(int('11111', 2)).eq(0))) \
    .median() \
    .clip(points.geometry().bounds())

# Use estas bandas para la prediccion.
bands = ['SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7', 'ST_B10']

# %% [markdown]
# **Visualizemos los datos de entrada**

# %%
center = points.geometry().centroid().coordinates().getInfo()
print(points.first().getInfo())
mapdisplay(center,{'train_dataset':points.getInfo(),
                   'image':image.getMapId({'bands':['SR_B5','SR_B4','SR_B3'],'gamma':1.4})})
# Out:
# {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-122.27096557617189, 37.820452055421086]}, 'id': '00000000000000000003', 'properties': {'landcover': 0}}
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1f0ca6f514f1816cdf87c092f0a4f97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1f0ca6f514f1816cdf87c092f0a4f97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1f0ca6f514f1816cdf87c092f0a4f97 = L.map(
#                 &quot;map_a1f0ca6f514f1816cdf87c092f0a4f97&quot;,
#                 {
#                     center: [37.778253523653376, -122.37538216245599],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a18b58efffefc23188f95b9a85be7b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4a18b58efffefc23188f95b9a85be7b1.addTo(map_a1f0ca6f514f1816cdf87c092f0a4f97);
#
#
#
#         function geo_json_cf3a700a03999e414a06f9f75495eac2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_cf3a700a03999e414a06f9f75495eac2 = L.geoJson(null, {
#                 onEachFeature: geo_json_cf3a700a03999e414a06f9f75495eac2_onEachFeature,
#
#         });
#
#         function geo_json_cf3a700a03999e414a06f9f75495eac2_add (data) {
#             geo_json_cf3a700a03999e414a06f9f75495eac2
#                 .addData(data);
#         }
#             geo_json_cf3a700a03999e414a06f9f75495eac2_add({&quot;columns&quot;: {&quot;landcover&quot;: &quot;Long&quot;, &quot;system:index&quot;: &quot;String&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.27096557617189, 37.820452055421086], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000003&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.2723388671875, 37.828587698949825], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000004&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.28195190429686, 37.82696064199382], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000005&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.28126525878908, 37.81882481909333], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000006&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.28950500488281, 37.81665511485429], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000007&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.29362487792969, 37.84341033205656], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000008&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.28607177734376, 37.84702517033112], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000009&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.27302551269531, 37.849193981623955], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0000000000000000000a&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.28057861328124, 37.86545803289311], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0000000000000000000b&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.2929382324219, 37.85624217776181], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0000000000000000000c&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.39799499511719, 37.785187237567705], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0000000000000000000f&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.4089813232422, 37.78247386188714], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000010&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.41859436035156, 37.7835592241132], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000011&quot;, &quot

# %% [markdown]
# **Clasificar una imagen landsat 8 usando arboles de decision (CART)**

# %%
# Esta propiedad de la tabla almacena el target (cobertura del suelo).
label = 'landcover'

# Superponga los puntos en las imagenes para obtener los datos de entrenamiento.
# Generando la data para entrenar
training = image.select(bands).sampleRegions( #seleccion de variables predictoras X
  collection = points, # el target  o Y
  properties = [label], # el nombre del Y
  scale = 30)
training.first().getInfo()

# Entrena un modelo clasificador CART con parámetros predeterminados.
trained = ee.Classifier.smileCart().train(training, label, bands)

# Clasifique la imagen con las mismas bandas utilizadas para el entrenamiento.
# Ahora el modelo clasificara con lo que ha entrenado, el resto de la imagen
classified = image.select(bands).classify(trained)

# %%
mapdisplay(center,{'train_dataset':points.getInfo(),
                   'image':image.getMapId({'bands':['SR_B5','SR_B4','SR_B3'],'gamma':1.4}),
                   'clasificacion':classified.getMapId({'min': 0, 'max': 2, 'palette': ['red', 'green', 'blue']})})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71a8d7d4d3e4b7b0d5210ce438caa7c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71a8d7d4d3e4b7b0d5210ce438caa7c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71a8d7d4d3e4b7b0d5210ce438caa7c9 = L.map(
#                 &quot;map_71a8d7d4d3e4b7b0d5210ce438caa7c9&quot;,
#                 {
#                     center: [37.778253523653376, -122.37538216245599],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5fdd35afd6780cf61c8252aa9cd8c4b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5fdd35afd6780cf61c8252aa9cd8c4b7.addTo(map_71a8d7d4d3e4b7b0d5210ce438caa7c9);
#
#
#
#         function geo_json_153a686fd5958602fba6b849a60c6f7d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_153a686fd5958602fba6b849a60c6f7d = L.geoJson(null, {
#                 onEachFeature: geo_json_153a686fd5958602fba6b849a60c6f7d_onEachFeature,
#
#         });
#
#         function geo_json_153a686fd5958602fba6b849a60c6f7d_add (data) {
#             geo_json_153a686fd5958602fba6b849a60c6f7d
#                 .addData(data);
#         }
#             geo_json_153a686fd5958602fba6b849a60c6f7d_add({&quot;columns&quot;: {&quot;landcover&quot;: &quot;Long&quot;, &quot;system:index&quot;: &quot;String&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.27096557617189, 37.820452055421086], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000003&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.2723388671875, 37.828587698949825], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000004&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.28195190429686, 37.82696064199382], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000005&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.28126525878908, 37.81882481909333], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000006&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.28950500488281, 37.81665511485429], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000007&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.29362487792969, 37.84341033205656], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000008&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.28607177734376, 37.84702517033112], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000009&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.27302551269531, 37.849193981623955], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0000000000000000000a&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.28057861328124, 37.86545803289311], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0000000000000000000b&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.2929382324219, 37.85624217776181], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0000000000000000000c&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.39799499511719, 37.785187237567705], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0000000000000000000f&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.4089813232422, 37.78247386188714], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000010&quot;, &quot;properties&quot;: {&quot;landcover&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-122.41859436035156, 37.7835592241132], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;00000000000000000011&quot;, &quot

# %%
#Esto se debe hacer con una base aparte no la de entrenamiento, a esta se llama base de testeo
train_accuracy = trained.confusionMatrix()

print('Validation error matrix: ', train_accuracy.getInfo())
print('Validation overall accuracy: ', train_accuracy.accuracy().getInfo())
# Out:
# Validation error matrix:  [[32, 0, 0], [0, 31, 0], [0, 0, 34]]
# Validation overall accuracy:  1

# %% [markdown]
# Este siguiente ejemplo utiliza un clasificador **Random Forest** con 10 arboles ([Breiman 2001](https://rd.springer.com/article/10.1023/A:1010933404324)). Para evaluar la precision de un clasificador, utilizamos una **matriz de confusion**(Stehman 1997).

# %%
# Las imagenes de entrada son un compuesto Landsat 8 sin nubes.
center = [-62.836, -9.2399]
l8 = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')\
       .filterBounds(ee.Geometry.Point(center))

image = l8.filterDate('2018-01-01', '2018-12-31') \
    .map(lambda img: img.updateMask(img.select('QA_PIXEL').bitwiseAnd(int('11111', 2)).eq(0))) \
    .median()


# Use estas bandas para la prediccion.
bands = ['SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7', 'ST_B10'];

# Poligonos creados manualmente.
# Estos poligonos van a servir como nuestra base de datos con target (Y), y GEE tomara puntos aleatorios dentro de estos poligonos con sus respectivas clases (Y)
forest1 = ee.Geometry.Rectangle(-63.0187, -9.3958, -62.9793, -9.3443)
forest2 = ee.Geometry.Rectangle(-62.8145, -9.206, -62.7688, -9.1735)
nonForest1 = ee.Geometry.Rectangle(-62.8161, -9.5001, -62.7921, -9.4486)
nonForest2 = ee.Geometry.Rectangle(-62.6788, -9.044, -62.6459, -8.9986)

# Hacer un FeatureCollection de las geometrias hechas a mano.
polygons = ee.FeatureCollection([
  ee.Feature(nonForest1, {'class': 0}),
  ee.Feature(nonForest2, {'class': 0}),
  ee.Feature(forest1, {'class': 1}),
  ee.Feature(forest2, {'class': 1}),
])

# Obtenga los valores para todos los pixeles en cada poligono en el entrenamiento.
# Obtenga la muestra de los poligonos FeatureCollection.
# Mantenga esta lista de propiedades de los poligonos.
# Establezca la escala para obtener pixeles Landsat en los poligonos.
training = image.sampleRegions(
  collection = polygons,
  properties = ['class'],  #como aca hay una propiedad no es necesario colocarla
  scale = 30
)


# Crear un clasificador RF con parámetros personalizados.
classifier = ee.Classifier.smileRandomForest(10)

# Entrenar el clasificador
trained = classifier.train(training, 'class', bands)

# Clasificar la imagen
classified = image.classify(trained)

# %%
mapdisplay(center, {'composite':image.getMapId({'bands': ['SR_B4', 'SR_B3', 'SR_B2'], 'gamma': 2},),
                    'deforestation': classified.getMapId({'min': 0, 'max': 1, 'palette': ['red', 'green']}),
                    'polygon':polygons.getInfo()})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_30f7fefdf985d42a642d72d79ddc89f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_30f7fefdf985d42a642d72d79ddc89f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_30f7fefdf985d42a642d72d79ddc89f5 = L.map(
#                 &quot;map_30f7fefdf985d42a642d72d79ddc89f5&quot;,
#                 {
#                     center: [-9.2399, -62.836],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67f18b1bcc2c8567e64948b126ef9d65 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_67f18b1bcc2c8567e64948b126ef9d65.addTo(map_30f7fefdf985d42a642d72d79ddc89f5);
#
#
#             var tile_layer_e202ebb6ddaa7096da61eb88f5fc4ec9 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-jtantaroman/maps/45dbcbe9d427d0510fb82088c8738dc7-b9ad97dfae379ab60db7b200804288d1/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e202ebb6ddaa7096da61eb88f5fc4ec9.addTo(map_30f7fefdf985d42a642d72d79ddc89f5);
#
#
#             var tile_layer_eeffe0a360e103c8cf1ea7ceee995e93 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-jtantaroman/maps/6b88af307a6ca273c0fc0d4c4ec1b745-4dec003d4e802143a2a8b0cdf61e8e31/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eeffe0a360e103c8cf1ea7ceee995e93.addTo(map_30f7fefdf985d42a642d72d79ddc89f5);
#
#
#
#         function geo_json_8ea4654bfa2c05129a1d098c6cae17ad_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8ea4654bfa2c05129a1d098c6cae17ad = L.geoJson(null, {
#                 onEachFeature: geo_json_8ea4654bfa2c05129a1d098c6cae17ad_onEachFeature,
#
#         });
#
#         function geo_json_8ea4654bfa2c05129a1d098c6cae17ad_add (data) {
#             geo_json_8ea4654bfa2c05129a1d098c6cae17ad
#                 .addData(data);
#         }
#             geo_json_8ea4654bfa2c05129a1d098c6cae17ad_add({&quot;columns&quot;: {&quot;class&quot;: &quot;Integer&quot;, &quot;system:index&quot;: &quot;String&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-62.8161, -9.5001], [-62.7921, -9.5001], [-62.7921, -9.4486], [-62.8161, -9.4486], [-62.8161, -9.5001]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;class&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-62.6788, -9.044], [-62.6459, -9.044], [-62.6459, -8.9986], [-62.6788, -8.9986], [-62.6788, -9.044]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;class&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-63.0187, -9.3958], [-62.9793, -9.3958], [-62.9793, -9.3443], [-63.0187, -9.3443], [-63.0187, -9.3958]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;class&quot;: 1}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-62.8145, -9.206], [-62.7688, -9.206], [-62.7688, -9.1735], [-62.8145, -9.1735], [-62.8145, -9.206]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;class&quot;: 1}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_8ea4654bfa2c05129a1d098c6cae17ad.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_8ea4654bfa2c05129a1d098c6cae17ad.addTo(map_30f7fefdf985d42a642d72d79ddc89f5);
#
#
#             var layer_control_41700ca6f277c526437e667eb70fe317_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_67f18b1bcc2c8567e64948b126ef9d65,
#                 },
#                 overlays :  {
#                     &quot;composite&quot; : tile_layer_e202ebb6ddaa7096da61eb88f5fc4ec9,
#                     &quot;deforestation&quot; : tile_layer_eeffe0a360e103c8cf1ea7ceee995e93,
#                     &quot;polygon&quot; : geo_json_8ea4654bfa2c05129a1d098c6cae17ad,
#                 },
#             };

# %%
train_accuracy = training.classify(trained)

# Obtenga una matriz de confusión que represente la precisión esperada.
trainAccuracy = train_accuracy.errorMatrix('class', 'classification')
print('Validation error matrix: ', trainAccuracy.getInfo())
print('Validation overall accuracy: ', trainAccuracy.accuracy().getInfo())
# Out:
# Validation error matrix:  [[37554, 1], [2, 48430]]
# Validation overall accuracy:  0.999965111005152

# %% [markdown]
# ### **2. Clasificacion no supervisada (clustering)**
#
# El modulo **ee.Clusterer** maneja la clasificacion no supervisada (o agrupamiento) en Earth Engine. Estos algoritmos se basan actualmente en los algoritmos con el mismo nombre en [Weka](https://www.cs.waikato.ac.nz/ml/weka/).
#
# Los clusteres se usan de la misma manera que los **clasificadores** en Earth Engine. El flujo de trabajo general para la agrupacion es el siguiente:
#
# 1. Ensamblar entidades con propiedades numericas en las que encontrar clusteres.
#
# 2. Instanciar un clusterer. Establezca sus parametros si es necesario.
#
# 3. Entrene al clusterer usando los datos de entrenamiento.
#
# 4. Aplique el clusterer a una colección de imagenes o caracteristicas.
#
# 5. Ponga nombre a los clusters.
#
# Los datos de entrenamiento son un **ee.FeatureCollection** con propiedades que se ingresaran al clusterer. A diferencia de los clasificadores, **no hay un valor de clase de entrada para un ee.Clusterer**. Al igual que los clasificadores, se espera que los datos para el entrenamiento y los pasos de aplicacion tengan el mismo numero de valores. Cuando se aplica un cluster entrenado a una imagen o tabla, asigna una ID de cluster entero a cada pixel o feature.

# %%
# Cargue un compuesto Landsat previamente calculado para la entrada.
Input = ee.Image('LANDSAT/LE7_TOA_1YEAR/2001')

# Defina una region en la que generar una muestra de la entrada.
region = ee.Geometry.Rectangle(29.7, 30, 32.5, 31.7)
region_img = ee.Image().paint(region, 0, 2)

# Mostrar la region de muestra.
center = [31.0,31.5]
mapdisplay(center,{'Region':region_img.getMapId()},zoom_start=8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19f13c66b7dc5ec369337cb66723df4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19f13c66b7dc5ec369337cb66723df4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19f13c66b7dc5ec369337cb66723df4c = L.map(
#                 &quot;map_19f13c66b7dc5ec369337cb66723df4c&quot;,
#                 {
#                     center: [31.5, 31.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a533c0391b17b3a0a998a7be77f32e6c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a533c0391b17b3a0a998a7be77f32e6c.addTo(map_19f13c66b7dc5ec369337cb66723df4c);
#
#
#             var tile_layer_dae2c99d45f3a6bcf73244bcb36ef79c = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-jtantaroman/maps/5e0a6aa772ee522bb578e1d4a4cd4276-b718a6ea8069f561b5a325eb702f0d1f/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dae2c99d45f3a6bcf73244bcb36ef79c.addTo(map_19f13c66b7dc5ec369337cb66723df4c);
#
#
#             var layer_control_e414f85b9305a0eaf0498c55bc2f5db6_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a533c0391b17b3a0a998a7be77f32e6c,
#                 },
#                 overlays :  {
#                     &quot;Region&quot; : tile_layer_dae2c99d45f3a6bcf73244bcb36ef79c,
#                 },
#             };
#             let layer_control_e414f85b9305a0eaf0498c55bc2f5db6 = L.control.layers(
#                 layer_control_e414f85b9305a0eaf0498c55bc2f5db6_layers.base_layers,
#                 layer_control_e414f85b9305a0eaf0498c55bc2f5db6_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_19f13c66b7dc5ec369337cb66723df4c);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Hacer el conjunto de datos de entrenamiento. Sample es para no supervisada, porque no necesitas una variable Y aca
# Tomara 5mil puntos de toda la region que se muestra en la parte superior
training = Input.sample(
  region=region,
  scale=30,
  numPixels=5000
)

# Instanciar al clusterer y entrenarlo.
clusterer = ee.Clusterer.wekaKMeans(15).train(training)

# Agrupe la entrada utilizando el agrupador capacitado.
result = Input.cluster(clusterer)
result_tk = result.randomVisualizer().getMapId()

# %%
# Kmeans es mucho mas rapido porque es un modelo que utiliza la gradiente y es mas paralelizable en GEE a diferencia de random forest
# Mostrar los grupos con colores aleatorios.
mapdisplay(center, {'results':result_tk},zoom_start=8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d68f918a83ee20b9f3eb4f90eb746a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d68f918a83ee20b9f3eb4f90eb746a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d68f918a83ee20b9f3eb4f90eb746a7 = L.map(
#                 &quot;map_4d68f918a83ee20b9f3eb4f90eb746a7&quot;,
#                 {
#                     center: [31.5, 31.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cdf4ded51210d43e38de05a0ccc18696 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cdf4ded51210d43e38de05a0ccc18696.addTo(map_4d68f918a83ee20b9f3eb4f90eb746a7);
#
#
#             var tile_layer_c4f49a4655918622f8eed3156e364c1e = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-jtantaroman/maps/a35787b5777d6bc7db4e8ebdb58c716a-768102d71bd00015c381d487c3e5b4c4/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c4f49a4655918622f8eed3156e364c1e.addTo(map_4d68f918a83ee20b9f3eb4f90eb746a7);
#
#
#             var layer_control_3f022955167b80870c400301b38bbf01_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_cdf4ded51210d43e38de05a0ccc18696,
#                 },
#                 overlays :  {
#                     &quot;results&quot; : tile_layer_c4f49a4655918622f8eed3156e364c1e,
#                 },
#             };
#             let layer_control_3f022955167b80870c400301b38bbf01 = L.control.layers(
#                 layer_control_3f022955167b80870c400301b38bbf01_layers.base_layers,
#                 layer_control_3f022955167b80870c400301b38bbf01_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_4d68f918a83ee20b9f3eb4f90eb746a7);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### **¿Dudas con este Jupyer-Notebook?**
#
# Estaremos felices de ayudarte!. Create una cuenta Github si es que no la tienes, luego detalla tu problema ampliamente en: https://github.com/csaybar/EarthEngineMasterGIS/issues
#
# **Tienes que dar clic en el boton verde!**
#
# <center>
# <img src="https://user-images.githubusercontent.com/16768318/79680748-d5511000-81d8-11ea-9f89-44bd010adf69.png" width = 70%>
# </center>
